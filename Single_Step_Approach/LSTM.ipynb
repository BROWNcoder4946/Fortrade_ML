# %% [markdown]
# # Preprocessing Forex data

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Load the data
data = pd.read_csv('EURUSD_data')

# Select features and target
features = data[['Open', 'High', 'Low', 'Close', 'Adj Close']]
target = data['Close']

# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(features)

# Create sequences of data for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length, 3])  # Use the 'Close' price as target
    return np.array(X), np.array(y)

seq_length = 60  # Using 60 days of data to predict the next day's price
X, y = create_sequences(scaled_data, seq_length)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %% [markdown]
# # Building LSTM model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Initialize the model
model = Sequential()

# LSTM layer 1
model.add(LSTM(units=100, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))

# LSTM layer 2
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Model summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 60, 100)           42400
#
#  dropout_8 (Dropout)         (None, 60, 100)           0
#
#  lstm_9 (LSTM)               (None, 50)                30200
#
#  dropout_9 (Dropout)         (None, 50)                0
#
#  dense_4 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 72651 (283.79 KB)
# Trainable params: 72651 (283.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training the model

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=120, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/120
# 64/64 [==============================] - 4s 39ms/step - loss: 0.0162 - val_loss: 7.5230e-04
# Epoch 2/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0029 - val_loss: 7.0293e-04
# Epoch 3/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0025 - val_loss: 6.5610e-04
# Epoch 4/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0024 - val_loss: 6.5476e-04
# Epoch 5/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0022 - val_loss: 6.2813e-04
# Epoch 6/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0022 - val_loss: 6.3407e-04
# Epoch 7/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0020 - val_loss: 7.8802e-04
# Epoch 8/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0021 - val_loss: 6.0639e-04
# Epoch 9/120
# 64/64 [==============================] - 2s 34ms/step - loss: 0.0022 - val_loss: 6.0115e-04
# Epoch 10/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0018 - val_loss: 5.7440e-04
# Epoch 11/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0019 - val_loss: 6.3399e-04
# Epoch 12/120
# 64/64 [==============================] - 2s 35ms/step - loss: 0.0018 - val_loss: 8.3815e-04
# Epoch 13/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0018 - val_loss: 4.9407e-04
# Epoch 14/120
# 64/64 [==============================] - 2s 34ms/step - loss: 0.0016 - val_loss: 5.1066e-04
# Epoch 15/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0015 - val_loss: 4.9181e-04
# Epoch 16/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0017 - val_loss: 5.6132e-04
# Epoch 17/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0017 - val_loss: 7.2250e-04
# Epoch 18/120
# 64/64 [==============================] - 2s 34ms/step - loss: 0.0015 - val_loss: 4.7199e-04
# Epoch 19/120
# 64/64 [==============================] - 2s 34ms/step - loss: 0.0015 - val_loss: 5.0765e-04
# Epoch 20/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0015 - val_loss: 6.3660e-04
# Epoch 21/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0014 - val_loss: 4.4347e-04
# Epoch 22/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0013 - val_loss: 4.6022e-04
# Epoch 23/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0012 - val_loss: 4.6810e-04
# Epoch 24/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0013 - val_loss: 5.3926e-04
# Epoch 25/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0012 - val_loss: 4.5673e-04
# Epoch 26/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0012 - val_loss: 5.3100e-04
# Epoch 27/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0011 - val_loss: 5.4460e-04
# Epoch 28/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0012 - val_loss: 5.3887e-04
# Epoch 29/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0012 - val_loss: 5.0035e-04
# Epoch 30/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0011 - val_loss: 3.6785e-04
# Epoch 31/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0011 - val_loss: 5.2226e-04
# Epoch 32/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0012 - val_loss: 3.6963e-04
# Epoch 33/120
# 64/64 [==============================] - 2s 34ms/step - loss: 9.8737e-04 - val_loss: 5.5062e-04
# Epoch 34/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0010 - val_loss: 4.1262e-04
# Epoch 35/120
# 64/64 [==============================] - 2s 32ms/step - loss: 0.0010 - val_loss: 3.4559e-04
# Epoch 36/120
# 64/64 [==============================] - 2s 34ms/step - loss: 0.0010 - val_loss: 4.5563e-04
# Epoch 37/120
# 64/64 [==============================] - 2s 33ms/step - loss: 0.0010 - val_loss: 4.5623e-04
# Epoch 38/120
# 64/64 [==============================] - 2s 35ms/step - loss: 8.5543e-04 - val_loss: 3.2601e-04
# Epoch 39/120
# 64/64 [==============================] - 2s 33ms/step - loss: 7.7844e-04 - val_loss: 3.2284e-04
# Epoch 40/120
# 64/64 [==============================] - 2s 33ms/step - loss: 8.9976e-04 - val_loss: 4.3722e-04
# Epoch 41/120
# 64/64 [==============================] - 2s 33ms/step - loss: 8.2605e-04 - val_loss: 3.0902e-04
# Epoch 42/120
# 64/64 [==============================] - 2s 33ms/step - loss: 7.8662e-04 - val_loss: 3.4592e-04
# Epoch 43/120
# 64/64 [==============================] - 2s 33ms/step - loss: 7.6336e-04 - val_loss: 2.9894e-04
# Epoch 44/120
# 64/64 [==============================] - 2s 33ms/step - loss: 7.5965e-04 - val_loss: 4.0866e-04
# Epoch 45/120
# 64/64 [==============================] - 2s 33ms/step - loss: 8.1011e-04 - val_loss: 3.4417e-04
# Epoch 46/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.4405e-04 - val_loss: 3.2437e-04
# Epoch 47/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.1579e-04 - val_loss: 2.8311e-04
# Epoch 48/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.5494e-04 - val_loss: 4.0539e-04
# Epoch 49/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.8636e-04 - val_loss: 2.8262e-04
# Epoch 50/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.8622e-04 - val_loss: 3.1462e-04
# Epoch 51/120
# 64/64 [==============================] - 2s 34ms/step - loss: 7.2557e-04 - val_loss: 3.0319e-04
# Epoch 52/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.1454e-04 - val_loss: 2.8778e-04
# Epoch 53/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.6235e-04 - val_loss: 3.7328e-04
# Epoch 54/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.0545e-04 - val_loss: 2.6043e-04
# Epoch 55/120
# 64/64 [==============================] - 2s 34ms/step - loss: 5.7018e-04 - val_loss: 2.6554e-04
# Epoch 56/120
# 64/64 [==============================] - 2s 33ms/step - loss: 5.6005e-04 - val_loss: 2.8932e-04
# Epoch 57/120
# 64/64 [==============================] - 2s 33ms/step - loss: 6.3150e-04 - val_loss: 3.7965e-04
# Epoch 58/120
# 64/64 [==============================] - 2s 33ms/step - loss: 5.9981e-04 - val_loss: 3.2406e-04
# Epoch 59/120
# 64/64 [==============================] - 2s 34ms/step - loss: 5.2283e-04 - val_loss: 2.3879e-04
# Epoch 60/120
# 64/64 [==============================] - 2s 33ms/step - loss: 5.4785e-04 - val_loss: 2.9757e-04
# Epoch 61/120
# 64/64 [==============================] - 2s 34ms/step - loss: 5.4140e-04 - val_loss: 3.4600e-04
# Epoch 62/120
# 64/64 [==============================] - 2s 34ms/step - loss: 6.1391e-04 - val_loss: 2.4059e-04
# Epoch 63/120
# 64/64 [==============================] - 2s 34ms/step - loss: 5.9228e-04 - val_loss: 2.2536e-04
# Epoch 64/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.9494e-04 - val_loss: 2.3025e-04
# Epoch 65/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.9913e-04 - val_loss: 2.3015e-04
# Epoch 66/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.4845e-04 - val_loss: 2.5812e-04
# Epoch 67/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.8350e-04 - val_loss: 2.7356e-04
# Epoch 68/120
# 64/64 [==============================] - 2s 34ms/step - loss: 5.4052e-04 - val_loss: 2.1287e-04
# Epoch 69/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.4138e-04 - val_loss: 2.6827e-04
# Epoch 70/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.5698e-04 - val_loss: 2.3076e-04
# Epoch 71/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.3336e-04 - val_loss: 2.8507e-04
# Epoch 72/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.0402e-04 - val_loss: 2.5497e-04
# Epoch 73/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.1631e-04 - val_loss: 2.0487e-04
# Epoch 74/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.3253e-04 - val_loss: 2.2465e-04
# Epoch 75/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.5810e-04 - val_loss: 1.9301e-04
# Epoch 76/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.1237e-04 - val_loss: 1.9224e-04
# Epoch 77/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.8030e-04 - val_loss: 1.8730e-04
# Epoch 78/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.0472e-04 - val_loss: 1.8840e-04
# Epoch 79/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.9347e-04 - val_loss: 1.8679e-04
# Epoch 80/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.5377e-04 - val_loss: 4.5993e-04
# Epoch 81/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.6137e-04 - val_loss: 3.4385e-04
# Epoch 82/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.9698e-04 - val_loss: 3.3488e-04
# Epoch 83/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.8275e-04 - val_loss: 1.7813e-04
# Epoch 84/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.8743e-04 - val_loss: 1.6971e-04
# Epoch 85/120
# 64/64 [==============================] - 2s 35ms/step - loss: 4.6446e-04 - val_loss: 2.3866e-04
# Epoch 86/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.7785e-04 - val_loss: 2.6491e-04
# Epoch 87/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.2042e-04 - val_loss: 6.0516e-04
# Epoch 88/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.0006e-04 - val_loss: 1.6776e-04
# Epoch 89/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.3686e-04 - val_loss: 1.6912e-04
# Epoch 90/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.1481e-04 - val_loss: 3.3731e-04
# Epoch 91/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.5133e-04 - val_loss: 1.7172e-04
# Epoch 92/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.6939e-04 - val_loss: 1.5632e-04
# Epoch 93/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.3221e-04 - val_loss: 2.7738e-04
# Epoch 94/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.5380e-04 - val_loss: 1.4714e-04
# Epoch 95/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.5548e-04 - val_loss: 1.4988e-04
# Epoch 96/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.2602e-04 - val_loss: 1.5635e-04
# Epoch 97/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.6689e-04 - val_loss: 1.4050e-04
# Epoch 98/120
# 64/64 [==============================] - 2s 34ms/step - loss: 2.9414e-04 - val_loss: 1.3891e-04
# Epoch 99/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.4635e-04 - val_loss: 4.2165e-04
# Epoch 100/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.0953e-04 - val_loss: 1.6276e-04
# Epoch 101/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.2767e-04 - val_loss: 3.5709e-04
# Epoch 102/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.5411e-04 - val_loss: 1.5088e-04
# Epoch 103/120
# 64/64 [==============================] - 2s 34ms/step - loss: 4.1473e-04 - val_loss: 1.3857e-04
# Epoch 104/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.6476e-04 - val_loss: 2.1716e-04
# Epoch 105/120
# 64/64 [==============================] - 2s 35ms/step - loss: 2.9942e-04 - val_loss: 1.3636e-04
# Epoch 106/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.6598e-04 - val_loss: 1.9995e-04
# Epoch 107/120
# 64/64 [==============================] - 2s 35ms/step - loss: 2.9736e-04 - val_loss: 2.5676e-04
# Epoch 108/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.3714e-04 - val_loss: 1.8536e-04
# Epoch 109/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.4092e-04 - val_loss: 1.4930e-04
# Epoch 110/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.2966e-04 - val_loss: 1.4402e-04
# Epoch 111/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.3126e-04 - val_loss: 1.2672e-04
# Epoch 112/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.1602e-04 - val_loss: 2.0323e-04
# Epoch 113/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.1880e-04 - val_loss: 1.1597e-04
# Epoch 114/120
# 64/64 [==============================] - 2s 35ms/step - loss: 4.1971e-04 - val_loss: 1.6414e-04
# Epoch 115/120
# 64/64 [==============================] - 2s 34ms/step - loss: 3.0977e-04 - val_loss: 1.4215e-04
# Epoch 116/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.3756e-04 - val_loss: 1.8111e-04
# Epoch 117/120
# 64/64 [==============================] - 2s 34ms/step - loss: 2.9520e-04 - val_loss: 1.7192e-04
# Epoch 118/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.2125e-04 - val_loss: 1.6823e-04
# Epoch 119/120
# 64/64 [==============================] - 2s 35ms/step - loss: 3.2192e-04 - val_loss: 2.8149e-04
# Epoch 120/120
# 64/64 [==============================] - 2s 35ms/step - loss: 2.9932e-04 - val_loss: 1.1276e-04

# %% [markdown]
# # Saving the model using Pickle

# %%
import pickle

# Assume 'model' is your trained LSTM model
model_filename = 'LSTM_model.pkl'

# Save the model
with open(model_filename, 'wb') as file:
    pickle.dump(model, file)

print(f"Model saved as {model_filename}")
# Out:
# Model saved as LSTM_model.pkl

# %%
# Loading the model
import pickle
with open('LSTM_model.pkl', 'rb') as file:
    model = pickle.load(file)

print("Model loaded successfully")
# Out:
# Model loaded successfully

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ### 1. Numerical

# %%
# Predicting on test data
predicted_prices = model.predict(X_test)

# Inverse transform the predicted and actual values to get them in the original scale
predicted_prices = scaler.inverse_transform(np.concatenate([X_test[:, -1, :-1], predicted_prices], axis=1))[:, -1]
actual_prices = scaler.inverse_transform(np.concatenate([X_test[:, -1, :-1], y_test.reshape(-1, 1)], axis=1))[:, -1]

# Evaluate the model
mse = np.mean((predicted_prices - actual_prices) ** 2)
print(f"Mean Squared Error: {mse}")
# Out:
# 16/16 [==============================] - 1s 10ms/step
# Mean Squared Error: 2.118742062866888e-05

# %%
from sklearn.metrics import r2_score
# Calculate R-squared
r_squared = r2_score(actual_prices, predicted_prices)
print(f"R-squared: {r_squared}")
# Out:
# R-squared: 0.9859677022488446

# %%
import numpy as np
import statsmodels.api as sm

# Adding a constant to the predicted prices to represent the intercept
X = sm.add_constant(predicted_prices)

# Fit the model (y = actual_prices)
model = sm.OLS(actual_prices, X).fit()

# Get the p-values
p_values = model.pvalues
print(f"P-value of the model: {p_values[1]}")

# Alternatively, print the summary of the model to see all details
print(model.summary())
# Out:
# P-value of the model: 0.0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                 3.758e+04
# Date:                Tue, 27 Aug 2024   Prob (F-statistic):               0.00
# Time:                        14:28:50   Log-Likelihood:                 2030.1
# No. Observations:                 509   AIC:                            -4056.
# Df Residuals:                     507   BIC:                            -4048.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0142      0.006     -2.547      0.011      -0.025      -0.003
# x1             1.0142      0.005    193.849      0.000       1.004       1.024
# ==============================================================================
# Omnibus:                        4.442   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.108   Jarque-Bera (JB):                5.444
# Skew:                          -0.051   Prob(JB):                       0.0657
# Kurtosis:                       3.496   Cond. No.                         56.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 3. Graphical

# %%
import matplotlib.pyplot as plt

# Plot the actual vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(actual_prices, color='blue', label='Actual Prices')
plt.plot(predicted_prices, color='red', label='Predicted Prices')
plt.title('Actual vs Predicted Forex Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
